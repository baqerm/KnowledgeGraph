# %%
import rdflib
from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph
import networkx as nx
import matplotlib.pyplot as plt

# %%
graph = rdflib.Graph()
metaGamDB = graph.parse("qlRDF-gam-output-metadata.ttl", format="ttl")

len(metaGamDB) 

for statement in metaGamDB:
    print(statement)
# Out:
# (rdflib.term.URIRef('http://qlRDF.com/LoanInfo/loannumber'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('gcid'))
# (rdflib.term.URIRef('http://qlRDF.com/PropertyInfo/loannumber'), rdflib.term.URIRef('http://qlRDF.com/Occupancy'), rdflib.term.Literal('occupancy'))
# (rdflib.term.URIRef('http://qlRDF.com/Identifier/loannumber'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('rocketaccountid'))
# (rdflib.term.URIRef('http://qlRDF.com/PropertyInfo/loannumber'), rdflib.term.URIRef('http://qlRDF.com/AnnualPropTax'), rdflib.term.Literal('annual_property_tax', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('http://qlRDF.com/Source/loannumber'), rdflib.term.URIRef('http://qlRDF.com/Identifies'), rdflib.term.URIRef('http://qlRDF.com/Identifier/loannumber'))
# ...

# %% [markdown]
# ## Networkx to plot the graphs

# %%
G = rdflib_to_networkx_multidigraph(metaGamDB)

pos = nx.spring_layout(G, scale=5)
edge_labels = nx.get_edge_attributes(G, 'r')
nx.draw_networkx_edge_labels(G, pos, labels=edge_labels)
nx.draw(G, with_labels=True)

# %%
graph = rdflib.Graph()
gamDB = graph.parse("qlRDF-gam-output.ttl", format="ttl")

# %%
G = rdflib_to_networkx_multidigraph(gamDB)

# Plot Networkx instance of RDF Graph
pos = nx.spring_layout(G, scale=5)
edge_labels = nx.get_edge_attributes(G, 'r')
nx.draw_networkx_edge_labels(G, pos, labels=edge_labels)
nx.draw(G, with_labels=True)

# %%
graph = rdflib.Graph()
TestgamDB = graph.parse("test-gam.ttl", format="ttl")

# %%
import io
import pydotplus
import graphviz
from IPython.display import display, Image
from rdflib.tools.rdf2dot import rdf2dot

# %% [markdown]
# ## Using graphviz to plot graphs

# %%
def visualize(g):
    stream = io.StringIO()
    rdf2dot(g, stream, opts = {display})
    dg = pydotplus.graph_from_dot_data(stream.getvalue())
    png = dg.create_png()
    display(Image(png))

# %%
visualize(TestgamDB)

# %%
graph = rdflib.Graph()
metaGamDB = graph.parse("qlRDF-gam-output-metadata.ttl", format="ttl")

# %%
visualize(metaGamDB)

# %%
graph = rdflib.Graph()
level2 = graph.parse("qlRDF-level2-output.ttl", format="ttl")

# %%
visualize(level2)

# %%
graph = rdflib.Graph()
level1 = graph.parse("dataAsset-output.ttl", format="ttl")

# %%
visualize(level1)
